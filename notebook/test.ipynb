# %%
import os
import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd()).parent.absolute()))    
from src.crawl_data import get_funds_attributes

# %%
data = get_funds_attributes()

# %%
data.head()
# Out:
#    id                                              name shortName     code  \
# 0  68  QUỸ ĐẦU TƯ CỔ PHIẾU KINH TẾ HIỆN ĐẠI VINACAPITAL     VMEEF     VMPF
# 1  11        QUỸ ĐẦU TƯ LỢI THẾ CẠNH TRANH BỀN VỮNG SSI    SSISCA   SSISCA
# 2  46              QUỸ ĐẦU TƯ CỔ PHIẾU TĂNG TRƯỞNG VCBF  VCBF-MGF  VCBFMGF
# 3  14           QUỸ ĐẦU TƯ CỔ PHIẾU TRIỂN VỌNG BẢO VIỆT      BVPF     BVPF
# 4  49           QUỸ ĐẦU TƯ TĂNG TRƯỞNG DÀI HẠN VIỆT NAM      VLGF     VLGF
#
#      price       nav  lastYearNav  holdingVolume   firstIssueAt  \
# 0  10000.0  14915.06     11250.56     8512336.11  1681146000000
# 1  10000.0  39565.38     30573.98     3059332.43  1411664400000
# 2  10000.0  12575.45     10511.41     5964551.76  1635440400000
# 3  10000.0  20896.00     16999.00      433257.69  1482944400000
# 4  10000.0  12145.66      9528.71     1261664.30  1636995600000
#
#        approveAt                                        description  \
# ...

# %%
len(data.owner.drop_duplicates())
# Out:
# 22
